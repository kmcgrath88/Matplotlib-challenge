# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
combined_df = pd.merge(mouse_metadata, study_results, how='outer', on='Mouse ID')
combined_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the DataFrame.
combined_df.count()
combined_df['Mouse ID'].value_counts()
# Out:
# g989    13
# a262    10
# q633    10
# a401    10
# z578    10
#         ..
# d133     1
# v199     1
# u153     1
# n482     1
# h428     1
# Name: Mouse ID, Length: 249, dtype: int64

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_ID_df = combined_df[combined_df.duplicated(['Mouse ID','Timepoint'])]
duplicate_ID_df.set_index('Mouse ID')
# Out:
#          Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# Mouse ID
# g989         Propriva  Female          21          26          0
# g989         Propriva  Female          21          26          5
# g989         Propriva  Female          21          26         10
# g989         Propriva  Female          21          26         15
# g989         Propriva  Female          21          26         20
#
#           Tumor Volume (mm3)  Metastatic Sites
# Mouse ID
# g989               45.000000                 0
# g989               47.570392                 0
# g989               49.880528                 0
# g989               53.442020                 0
# g989               54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. --- same as above???

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = combined_df.drop_duplicates(['Mouse ID','Timepoint'], keep = 'first')
clean_df.head(20)
# Out:
#    Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0      k403     Ramicane    Male          21          16          0
# 1      k403     Ramicane    Male          21          16          5
# 2      k403     Ramicane    Male          21          16         10
# 3      k403     Ramicane    Male          21          16         15
# 4      k403     Ramicane    Male          21          16         20
# 5      k403     Ramicane    Male          21          16         25
# 6      k403     Ramicane    Male          21          16         30
# 7      k403     Ramicane    Male          21          16         35
# 8      k403     Ramicane    Male          21          16         40
# 9      k403     Ramicane    Male          21          16         45
# 10     s185    Capomulin  Female           3          17          0
# 11     s185    Capomulin  Female           3          17          5
# 12     s185    Capomulin  Female           3          17         10
# ...

# %%
# Checking the number of mice in the clean DataFrame.
clean_df.count()
# Out:
# Mouse ID              1888
# Drug Regimen          1888
# Sex                   1888
# Age_months            1888
# Weight (g)            1888
# Timepoint             1888
# Tumor Volume (mm3)    1888
# Metastatic Sites      1888
# dtype: int64

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
mean = clean_df['Tumor Volume (mm3)'].groupby('Drug Regimen').mean()
median = clean_df['Tumor Volume (mm3)'].groupby('Drug Regimen').median()
variance = clean_df['Tumor Volume (mm3)'].groupby('Drug Regimen').var()
stdev = clean_df['Tumor Volume (mm3)'].groupby('Drug Regimen').std()
sem = clean_df['Tumor Volume (mm3)'].groupby('Drug Regimen').sem()

summary_stat = {'Mean': mean, 'Median': median, 'Variance': variance, 'St. Deviation': stdev, 'SEM': sem}
summary_stat_df = pd.DataFrame(summary_stat)
summary_stat_df
#mean = np.mean(clean_df['Tumor Volume (mm3)'])
#print(mean)

# This method is the most straightforward, creating multiple series and putting them all together at the end.
# Out:
#                    Mean     Median   Variance  St. Deviation       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764       4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177       6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684       6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577       8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479       8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083       7.821003  0.581331
# Propriva      52.393463  50.909965  43.138803       6.568014  0.525862
# Ramicane      40.216745  40.673236  23.486704       4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562       7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355       6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# This method produces everything in a single groupby function.

#mean2 = clean_df[['Drug Regimen','Tumor Volume (mm3)']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-349897b46425> in <module>
#       2
#       3 # This method produces everything in a single groupby function.
# ----> 4 mean2 = clean_df[['Drug Regimen','Tumor Volume (mm3)']]
#
# ~\anaconda\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
# ...

# %% [markdown]
# ## Bar Plots

# %%
# Generate a bar plot showing the number of mice per time point for each treatment throughout the course of the study using pandas.

# %%
# Generate a bar plot showing the number of mice per time point for each treatment throughout the course of the study using pyplot.

# %% [markdown]
# ## Pie Plots

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens. Calculate the IQR and quantitatively determine if there are any potential outliers.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
