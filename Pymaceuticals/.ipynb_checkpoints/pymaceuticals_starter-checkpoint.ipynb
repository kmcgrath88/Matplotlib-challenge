# %% [markdown]
# # Observations and Insights

# %% [markdown]
# There are several observations and inferences that can be made about all of the drug regimens, especially the drug of interest, Capomulin, when treating squamous cell carcinoma (SCC). First, when looking at the summary statistics for all of the drug regimens as a whole, it is evident that Capomulin and Ramicane are the most effective. Capomulin and Ramicane appear to be equally effective in treating the SCC tumor growth. Both regimens have almost identical means, medians, variances, standard deviations, and standard error of means (SEM). However, it should be noted that Ramincane appears to be slightly more effective than Capomulin. Both drug regimens are significantly more effective than the other 8 treatments. The next three most effective drugs appear to be Propriva, Ceftamin, and Infubinol. However, all three of these drug regimens have mean and median tumor volumes approximately 9 or more cubic millimeters above Capomulin and Ramicane. In addition, Propriva, Ceftamin, and Infubinol have variances over 14 square millimeters above Ramicane and Capomulin, and standard deviations over 1.2 millimeters larger.
#
# When observing the bar graphs for the number of mice per timepoint for each treatment regimen, it is clear that Capomulin and Ramicane have more observations across the mice and timepoints throughout the study compared to the other treatments.
#
# From the pie charts, we can conclude that the sample for the study was pretty even across mouse gender which removes some bias from the study as a whole. However, I would be interested to see the mouse gender per drug treatment to determine if it was unbiased across all of the treatments.
#
# Looking at the IQR calculations and boxplots for the four promising treatment regimens of Capomulin, Ramicane, Infubinol, and Ceftamin, we can draw a few conclusions. Capomulin has the smallest IQR and indicates that 50% of the mice on this treatment had a final tumor volume from 32.18 cubic millimeters to 40.16 cubic millimeters. In addition, 75% of the mice on this drug regimen had a final tumor volume of under 40.16 cubic millimeters. Capomulin and Ramicane’s maximum tumor volume values are smaller than the first quartile of Infubinol and ceftamin. This indicates that 100% of the final tumor volume values for Capomulin and Ramicane are smaller than more than 75% of the final tumor volume values for Infubinol and Ceftamin. Lastly, Capomulin and Ramicane have very similar boxplots which once again indicates these treatment options are relatively equal in effectiveness.
#
# From the line plot of the individual mouse, it is evident that Capomulin was an effective treatment for it’s SCC tumor. Mouse s185’s tumor decreased by about 20 cubic millimeters over the 45 day study, over 40% of its original size.
#
# Finally, from the scatterplot, correlation, and regression of mouse weight compared to tumor volume for Capomulin, we can conclude that there is a strong positive correlation between a mouse's weight and the tumor volume size. The more a mouse weighs, the larger the average tumor volume. The strong positive correlation is indicated by the positive trend in the scatterplot and the 0.842 correlation coefficient, r.
#
# To conclude, according to this study the most effective treatments are Capomulin and Ramicane. This study proves both are effective drugs regimens for SCC tumors compared to several other treatments. We can argue that Capomulin is one of the most effective treatments on the market for treating squamous cell carcinoma .

# %% [markdown]
# # Dependencies and Setup

# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

#Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

#Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

#Combine the data into a single dataset
combined_df = pd.merge(mouse_metadata, study_results, how='outer', on='Mouse ID')
combined_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
#Checking the number of mice in the DataFrame.
combined_df.count()
# Out:
# Mouse ID              1893
# Drug Regimen          1893
# Sex                   1893
# Age_months            1893
# Weight (g)            1893
# Timepoint             1893
# Tumor Volume (mm3)    1893
# Metastatic Sites      1893
# dtype: int64

# %% [markdown]
# # Clean DataFrame

# %%
#Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_ID = combined_df.loc[combined_df.duplicated(subset=['Mouse ID','Timepoint']),'Mouse ID'].unique()
print(duplicate_ID)
# Out:
# ['g989']

# %%
#Optional: Get all the data for the duplicate mouse ID.
duplicate_ID_df = combined_df.loc[combined_df['Mouse ID'] == 'g989']
duplicate_ID_df
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
#Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = combined_df.loc[combined_df['Mouse ID']!= 'g989']
clean_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
#Checking the number of mice in the clean DataFrame.
clean_df.count()
# Out:
# Mouse ID              1880
# Drug Regimen          1880
# Sex                   1880
# Age_months            1880
# Weight (g)            1880
# Timepoint             1880
# Tumor Volume (mm3)    1880
# Metastatic Sites      1880
# dtype: int64

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume 
#for each regimen.This method is the most straightforward, creating multiple series and putting them all together at the end.

mean = clean_df.groupby('Drug Regimen').mean()['Tumor Volume (mm3)']
median = clean_df.groupby('Drug Regimen').median()['Tumor Volume (mm3)']
variance = clean_df.groupby('Drug Regimen').var()['Tumor Volume (mm3)']
stdev = clean_df.groupby('Drug Regimen').std()['Tumor Volume (mm3)']
sem = clean_df.groupby('Drug Regimen').sem()['Tumor Volume (mm3)']

summary_stat = pd.DataFrame({'Mean Tumor Volume': mean,
                             'Median Tumor Volume': median,
                             'Tumor Volume Variance': variance,
                             'Tumor Volume Std. Dev.': stdev,
                             'Tumor Volume SEM': sem})
summary_stat
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Ramicane              40.216745            40.673236              23.486704
# Capomulin             40.675741            41.557809              24.947764
# Propriva              52.320930            50.446266              43.852013
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Zoniferol             53.236507            51.818479              48.533355
# Placebo               54.033581            52.288934              61.168083
# Stelasyn              54.233149            52.431737              59.450562
# Naftisol              54.331565            52.509285              66.173479
# Ketapril              55.235638            53.698743              68.553577
#
#               Tumor Volume Std. Dev.  Tumor Volume SEM
# Drug Regimen
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume 
#for each regimen. This method produces everything in a single groupby function.
summary_df = clean_df[['Drug Regimen','Tumor Volume (mm3)']]
summary_df = summary_df.rename(columns={'Tumor Volume (mm3)': 'Volume'})

summary_stat2 = summary_df.groupby(['Drug Regimen']).Volume.agg(['mean','median','var','std','sem'])
summary_stat2 = summary_stat2.rename(columns = {'mean' : 'Mean Tumor Volume',
                                                'median' : 'Median Tumor Volume',
                                                'var': 'Tumor Volume Variance',
                                                'std' : 'Tumor Volume Std. Dev.',
                                                'sem' : 'Tumor Volume SEM'})
summary_stat2
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume SEM
# Drug Regimen
# ...

# %% [markdown]
# ## Bar Plots

# %%
# Generate a bar plot showing the number of mice per time point for each treatment 
#throughout the course of the study using pandas.

#Filter the dataframe down only to those columns to chart
mouse_reg = clean_df[['Mouse ID', 'Drug Regimen']]

#Finding counts per drug regimen
mouse_count = mouse_reg['Drug Regimen'].value_counts()
#Storing drug regimen into variable
regimen = mouse_count.index.values

#Use DataFrame.plot() in order to create a bar chart of the data
mouse_reg_plot = mouse_count.plot(kind='bar', figsize=(12,7), align='center', xlim=(-.75, len(regimen)-.25),
                                  ylim=(0, max(mouse_count)+ 20), legend=True)

#Set title, labels
mouse_reg_plot.set_title('Number of Mice per Timepoint per Treatment Regimen')
mouse_reg_plot.set_xlabel('Drug Regimen')
mouse_reg_plot.set_xticklabels(regimen, rotation=45)
mouse_reg_plot.set_ylabel('Number of Mice')
plt.tight_layout()

# %%
# Generate a bar plot showing the number of mice per time point for each treatment throughout the course of the 
#study using pyplot.

#Filter the dataframe down only to those columns to chart
total_mice = clean_df[['Mouse ID', 'Drug Regimen']]

#Finding counts per drug regimen
mouse_count2 = total_mice['Drug Regimen'].value_counts()
#Storing drug regimen into variable
regimen2 = mouse_count2.index.values

#Creating bar graph
plt.figure(figsize=(12,7))
plt.bar(regimen, mouse_count2, align = 'center', label='Drug Regimen')

#Set title, labels, and limits
plt.title('Number of Mice per Timepoint per Treatment Regimen')
plt.xlabel('Drug Regimen')
plt.xticks(rotation=45)
plt.ylabel('Number of Mice')
plt.xlim(-.75, len(regimen2)-.25)
plt.ylim(0, max(mouse_count2)+ 20)
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Pie Plots

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

gender_df = clean_df.drop_duplicates(['Mouse ID','Sex'], keep='first') #Drop duplicates, keep mouse ID and sex
new_gender_df = gender_df[['Mouse ID','Sex']]
mouse_total = new_gender_df['Sex'].value_counts()   #Find total count of each sex

explode = (0.035,0)
mouse_total_pie = mouse_total.plot.pie(explode=explode, title='Mouse Gender', labels=['',''], #Create pie chart
                                       figsize=(10,5), autopct='%1.1f%%', shadow=True)
mouse_total_pie.set_ylabel('') 
plt.axis('equal') 
mouse_total_pie.legend(loc='best', labels=mouse_total.index.values)

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

gender2_df = clean_df.drop_duplicates(['Mouse ID','Sex'], keep='first') #Drop duplicates, keep mouse ID and sex
new_gender2_df = gender2_df[['Mouse ID', 'Sex']]
mouse_total2 = new_gender2_df['Sex'].value_counts()   #Find total count of each sex

explode = (0.035,0)
plt.figure(figsize=(10,5))  #Create pie chart
plt.pie(mouse_total2.values, autopct="%1.1f%%", explode=explode, shadow=True)

plt.ylabel('') #Set label, create equal axes
plt.title('Mouse Gender')
plt.axis('equal') 
plt.legend(loc='best', labels=mouse_total2.index.values)

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
#Calculate the final tumor volume of each mouse across four of the most promising treatment regimens.  
tumor_volume = clean_df.drop_duplicates(['Mouse ID','Drug Regimen'], keep='last')
tumor_volume = tumor_volume[['Mouse ID','Drug Regimen','Tumor Volume (mm3)', 'Timepoint']]
tumor_volume = tumor_volume.loc[(tumor_volume['Drug Regimen'] == 'Capomulin')
                               |(tumor_volume['Drug Regimen'] == 'Ramicane')
                               |(tumor_volume['Drug Regimen'] == 'Infubinol')
                               |(tumor_volume['Drug Regimen'] == 'Ceftamin'), :]
                                
tumor_volume
# Out:
#      Mouse ID Drug Regimen  Tumor Volume (mm3)  Timepoint
# 9        k403     Ramicane           22.050126         45
# 19       s185    Capomulin           23.343598         45
# 29       x401    Capomulin           28.484033         45
# 39       m601    Capomulin           28.430964         45
# 49       g791     Ramicane           29.128472         45
# ...       ...          ...                 ...        ...
# 1797     x822     Ceftamin           61.386660         45
# 1813     y163    Infubinol           67.685569         45
# 1845     y769     Ceftamin           68.594745         45
# 1855     y865     Ceftamin           64.729837         45
# 1872     z581    Infubinol           62.754451         45
#
# [100 rows x 4 columns]

# %%
#Calculate the IQR and quantitatively determine if there are any potential outliers.

drug_reg=['Capomulin','Ramicane','Infubinol','Ceftamin']  #Create list of drug regimens

def IQR(drug_input): #Create function for IQR calculations, locate drug regimen and tumor volume
    tumor_vol = tumor_volume.loc[(clean_df['Drug Regimen'] == drug_input),'Tumor Volume (mm3)']
        
    quartiles = tumor_vol.quantile([0.25,0.5,0.75])  #Find quartiles
    lowerq = round(quartiles[0.25], 2)
    upperq = round(quartiles[0.75], 2)
    iqr = round(upperq-lowerq, 2)  #Find IQR

    lower_bound = lowerq - (1.5*iqr)  #Find lower and upper bounds
    upper_bound = upperq + (1.5*iqr)
    
    outliers = tumor_vol.loc[(tumor_vol < lower_bound)|(tumor_vol > upper_bound)] #Find outliers
    print(f'For drug regimen {drug}:')
    print(f'The lower quartile is {lowerq} and the upper quartile is {upperq}. The IQR is {iqr}.')
        
    if not len(outliers):
        print(f'No potential outliers found for {drug}.\n')
    else:
        print(f'The following are potential outliers for {drug}: {outliers.values}\n')
    
for drug in drug_reg:
    IQR(drug)
# Out:
# For drug regimen Capomulin:
# The lower quartile is 32.38 and the upper quartile is 40.16. The IQR is 7.78.
# No potential outliers found for Capomulin.
#
# For drug regimen Ramicane:
# The lower quartile is 31.56 and the upper quartile is 40.66. The IQR is 9.1.
# No potential outliers found for Ramicane.
#
# For drug regimen Infubinol:
# The lower quartile is 54.05 and the upper quartile is 65.53. The IQR is 11.48.
# The following are potential outliers for Infubinol: [36.3213458]
#
# For drug regimen Ceftamin:
# The lower quartile is 48.72 and the upper quartile is 64.3. The IQR is 15.58.
# No potential outliers found for Ceftamin.

# %%
#Generate a box plot of the final tumor volume of each mouse across four regimens of interest  

cap_df = tumor_volume.loc[(tumor_volume['Drug Regimen'] == 'Capomulin'),:]  #Create dataframe for each drug
#cap_df.head()
#fig1, ax1 = plt.subplots()
#ax1.boxplot(cap_df['Tumor Volume (mm3)'])

ram_df = tumor_volume.loc[(tumor_volume['Drug Regimen'] == 'Ramicane'),:]
#ram_df.head()
#fig2, ax2 = plt.subplots()
#ax2.boxplot(ram_df['Tumor Volume (mm3)'])

inf_df = tumor_volume.loc[(tumor_volume['Drug Regimen'] == 'Infubinol'),:]
#inf_df.head()
#fig3, ax3 = plt.subplots()
#ax3.boxplot(inf_df['Tumor Volume (mm3)'])

ceft_df = tumor_volume.loc[(tumor_volume['Drug Regimen'] == 'Ceftamin'),:]
#ceft_df.head()
#fig4, ax4 = plt.subplots()
#ax4.boxplot(ceft_df['Tumor Volume (mm3)'])

labels = ['Capomulin','Ramicane', 'Infubinol', 'Ceftamin'] #Create labels, combine data frames to produce 4 boxplots on 
                                                           #same plot


data = [cap_df['Tumor Volume (mm3)'],ram_df['Tumor Volume (mm3)'], inf_df['Tumor Volume (mm3)'], ceft_df['Tumor Volume (mm3)']]
red_circle = dict(markerfacecolor='r', markersize=8)  #Create dictionary for outlier style
fig5, ax5 = plt.subplots(figsize=(10, 10))
ax5.set_title('Tumor Volume Across Four Promising Treatment Regimens')
ax5.boxplot(data, labels = labels, flierprops = red_circle) #Create boxplots, add labels, add outlier style
plt.ylabel('Final Tumor Volume (mm3)')
# Out:
# Text(0, 0.5, 'Final Tumor Volume (mm3)')

# %% [markdown]
# ## Line and Scatter Plots

# %%
#Pick one mouse from Capomulin
cap_df.head()
#I picked mouse ID s185
# Out:
#     Mouse ID Drug Regimen  Tumor Volume (mm3)  Timepoint
# 19      s185    Capomulin           23.343598         45
# 29      x401    Capomulin           28.484033         45
# 39      m601    Capomulin           28.430964         45
# 64      f966    Capomulin           30.485985         20
# 104     u364    Capomulin           31.023923         45

# %%
#Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

onemouse_cap = clean_df.loc[clean_df['Mouse ID']=='s185', :]  #Identify specific mouse ID
onemouse_cap_df = onemouse_cap[['Timepoint', 'Tumor Volume (mm3)']]  #Create dataframe for mouse ID
#onemouse_cap_df

plt.figure(figsize=(10,5))  #Set plot size, create line plot
plt.plot(onemouse_cap_df['Timepoint'],onemouse_cap_df['Tumor Volume (mm3)'])

plt.xlim(0,max(onemouse_cap_df['Timepoint']))  #Set x and y limits, labels and title
plt.ylim(0, max(onemouse_cap_df['Tumor Volume (mm3)'])+2)
plt.xlabel('Timepoint (days)')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Capomulin Treatment of Mouse s185')
# Out:
# Text(0.5, 1.0, 'Capomulin Treatment of Mouse s185')

# %%
#Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen

weight_vol = clean_df.loc[clean_df['Drug Regimen']=='Capomulin', :]  #Identify specific drug regimen
weight = weight_vol[['Mouse ID', 'Weight (g)']]  #Create new dataframe
weight_df = weight.groupby('Mouse ID').mean()  #Find mean of weight

average_vol = weight_vol[['Mouse ID', 'Tumor Volume (mm3)']]  #Create dataframe for mouse ID and tumor volume
average_vol_df = average_vol.groupby('Mouse ID').mean()  #Groupby mouse id, find mean

plt.scatter(weight_df, average_vol_df)  #Create scatter plot, assign labels and title                            
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.title('Mouse Weight vs Average Tumor Volume for Capomulin')
# Out:
# Text(0.5, 1.0, 'Mouse Weight vs Average Tumor Volume for Capomulin')

# %% [markdown]
# ## Correlation and Regression

# %%
#Calculate the correlation coefficient and linear regression model 
#for mouse weight and average tumor volume for the Capomulin regimen

(slope, intercept, rvalue, pvalue, stderr) = st.mstats.linregress(weight_df, average_vol_df)  #Create linear regression line
regress_values = weight_df * slope + intercept
linreg_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))  #Linear regression equation
print(f'The correlation coefficient, r, is: {rvalue}')
print(f'r-squared is: {rvalue**2}')

plt.scatter(weight_df, average_vol_df)  #Recreate same scatterplot from above, add linear regression line and equation
plt.plot(weight_df,regress_values,"r-")
plt.annotate(linreg_eq,(20,36),fontsize=15,color="red")

plt.xlabel('Weight (g)')  #Add labels and titles
plt.ylabel('Average Tumor Volume (mm3)')
plt.title('Mouse Weight vs Average Tumor Volume for Capomulin')
# Out:
# The correlation coefficient, r, is: 0.8419363424694718
# r-squared is: 0.7088568047708717
# Text(0.5, 1.0, 'Mouse Weight vs Average Tumor Volume for Capomulin')
